# %%
__author__ = "Julius Pinsker"
__copyright__ = "Copyright 2020, IMSAS - University of Bremen"
__credits__ = ["Julius Pinsker"]
__license__ = "GPL"
__version__ = "0.1"
__maintainer__ = "Julius Pinsker"
__email__ = "pinsker@uni-bremen.de"
__status__ = "Concept"

# %%
##Short      
import serial
serialPort = serial.Serial(port = "COM4", baudrate=57600,
                           bytesize=8, timeout=2, stopbits=serial.STOPBITS_ONE)
        
serialString = ""                           # Used to hold data coming over UART


while(1):

    # Wait until there is data waiting in the serial buffer
    if(serialPort.in_waiting > 0):

        # Read data out of the buffer until a carraige return / new line is found
        serialString = serialPort.readline()

        # Print the contents of the serial data
        print(serialString.decode('Ascii'))

        # Tell the device connected over the serial port that we recevied the data!
        # The b at the beginning is used to indicate bytes!
        serialPort.write(b"Thank you for sending data \r\n")

##Long but thourough
https://github.com/adamwtow/python-serial-monitor/blob/master/python-serial-monitor.py
# Out:
# -----------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/serial/serialposix.py in open(self)
#     264         try:
# --> 265             self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     266         except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'COM4'
#
# During handling of the above exception, another exception occurred:
#
# SerialExceptionTraceback (most recent call last)
# <ipython-input-4-0e4a075de9e1> in <module>
#       1 import serial
# ----> 2 serialPort = serial.Serial(port = "COM4", baudrate=115200,
#       3                            bytesize=8, timeout=2, stopbits=serial.STOPBITS_ONE)
#       4
#       5 serialString = ""                           # Used to hold data coming over UART
#
# ...

# %%
##Coordinates and Delays (List_content)    
import time
class Delay (my_delay):
    time.sleep(my_delay) # Sleep for (my_delay) seconds

#Global Variables
speed = 0 #in Hz

class Coordinate(object):
    def __init__(self,x,y):
        self.x = x
        self.y = y

    def getX(self):
        # Getter method for a Coordinate object's x coordinate.
        # Getter methods are better practice than just accessing an attribute directly
        return self.x

    def getY(self):
        # Getter method for a Coordinate object's y coordinate
        return self.y

    #Coordinates as String
    def __str__(self):
        return '<' + str(self.getX()) + ',' + str(self.getY()) + '>'
    
    #Are Both Coordinates equal?
    def __eq__(self, other):
        return self.y == other.y and self.x == other.x
    
    #Method to print Coordinates
    def __repr__(self):
        return "Coordinate(%d, %d)" % (self.x, self.y)

c1 = Coordinate(1, -8)
c2 = Coordinate(1, -8)
print(c1)
print(c2)
print(c1 == c2)

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'gui.ui'
#
# Created by: PyQt5 UI code generator 5.15.1
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(1501, 687)
        MainWindow.setAutoFillBackground(False)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.gridLayout_2 = QtWidgets.QGridLayout(self.centralwidget)
        self.gridLayout_2.setObjectName("gridLayout_2")
        self.verticalLayout_2 = QtWidgets.QVBoxLayout()
        self.verticalLayout_2.setObjectName("verticalLayout_2")
        self.listWidget = QtWidgets.QListWidget(self.centralwidget)
        self.listWidget.setObjectName("listWidget")
        item = QtWidgets.QListWidgetItem()
        self.listWidget.addItem(item)
        item = QtWidgets.QListWidgetItem()
        self.listWidget.addItem(item)
        item = QtWidgets.QListWidgetItem()
        self.listWidget.addItem(item)
        self.verticalLayout_2.addWidget(self.listWidget)
        self.pushButton_2 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_2.setObjectName("pushButton_2")
        self.verticalLayout_2.addWidget(self.pushButton_2)
        self.pushButton = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton.setObjectName("pushButton")
        self.verticalLayout_2.addWidget(self.pushButton)
        self.gridLayout_2.addLayout(self.verticalLayout_2, 0, 0, 1, 1)
        self.verticalLayout_4 = QtWidgets.QVBoxLayout()
        self.verticalLayout_4.setObjectName("verticalLayout_4")
        self.verticalLayout_3 = QtWidgets.QVBoxLayout()
        self.verticalLayout_3.setObjectName("verticalLayout_3")
        self.label_2 = QtWidgets.QLabel(self.centralwidget)
        self.label_2.setText("")
        self.label_2.setPixmap(QtGui.QPixmap("media/imsas_small.png"))
        self.label_2.setAlignment(QtCore.Qt.AlignBottom|QtCore.Qt.AlignHCenter)
        self.label_2.setObjectName("label_2")
        self.verticalLayout_3.addWidget(self.label_2)
        self.label = QtWidgets.QLabel(self.centralwidget)
        self.label.setLayoutDirection(QtCore.Qt.LeftToRight)
        self.label.setAutoFillBackground(False)
        self.label.setObjectName("label")
        self.verticalLayout_3.addWidget(self.label)
        self.speed_slider = QtWidgets.QSlider(self.centralwidget)
        self.speed_slider.setMinimum(50)
        self.speed_slider.setMaximum(10000)
        self.speed_slider.setOrientation(QtCore.Qt.Horizontal)
        self.speed_slider.setObjectName("speed_slider")
        self.verticalLayout_3.addWidget(self.speed_slider)
        self.speed_textbox = QtWidgets.QSpinBox(self.centralwidget)
        self.speed_textbox.setMinimum(50)
        self.speed_textbox.setMaximum(10000)
        self.speed_textbox.setObjectName("speed_textbox")
        self.verticalLayout_3.addWidget(self.speed_textbox)
        self.horizontalLayout_2 = QtWidgets.QHBoxLayout()
        self.horizontalLayout_2.setObjectName("horizontalLayout_2")
        self.speed_slowest = QtWidgets.QPushButton(self.centralwidget)
        self.speed_slowest.setObjectName("speed_slowest")
        self.horizontalLayout_2.addWidget(self.speed_slowest)
        self.speed_slow = QtWidgets.QPushButton(self.centralwidget)
        self.speed_slow.setObjectName("speed_slow")
        self.horizontalLayout_2.addWidget(self.speed_slow)
        self.speed_fast = QtWidgets.QPushButton(self.centralwidget)
        self.speed_fast.setObjectName("speed_fast")
        self.horizontalLayout_2.addWidget(self.speed_fast)
        self.speed_fastest = QtWidgets.QPushButton(self.centralwidget)
        self.speed_fastest.setObjectName("speed_fastest")
        self.horizontalLayout_2.addWidget(self.speed_fastest)
        self.verticalLayout_3.addLayout(self.horizontalLayout_2)
        self.verticalLayout_4.addLayout(self.verticalLayout_3)
        self.gridLayout_6 = QtWidgets.QGridLayout()
        self.gridLayout_6.setObjectName("gridLayout_6")
        self.move_right = QtWidgets.QPushButton(self.centralwidget)
        self.move_right.setText("")
        icon = QtGui.QIcon()
        icon.addPixmap(QtGui.QPixmap("media/arrow_right.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.move_right.setIcon(icon)
        self.move_right.setFlat(True)
        self.move_right.setObjectName("move_right")
        self.gridLayout_6.addWidget(self.move_right, 2, 2, 1, 1)
        self.move_left = QtWidgets.QPushButton(self.centralwidget)
        self.move_left.setText("")
        icon1 = QtGui.QIcon()
        icon1.addPixmap(QtGui.QPixmap("media/arrow_left.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.move_left.setIcon(icon1)
        self.move_left.setFlat(True)
        self.move_left.setObjectName("move_left")
        self.gridLayout_6.addWidget(self.move_left, 2, 0, 1, 1)
        self.pushButton_6 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_6.setTabletTracking(False)
        icon2 = QtGui.QIcon()
        icon2.addPixmap(QtGui.QPixmap("media/enter.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.pushButton_6.setIcon(icon2)
        self.pushButton_6.setFlat(False)
        self.pushButton_6.setObjectName("pushButton_6")
        self.gridLayout_6.addWidget(self.pushButton_6, 2, 1, 1, 1)
        self.reverse_y = QtWidgets.QCheckBox(self.centralwidget)
        self.reverse_y.setObjectName("reverse_y")
        self.gridLayout_6.addWidget(self.reverse_y, 0, 1, 1, 1)
        self.move_up = QtWidgets.QPushButton(self.centralwidget)
        self.move_up.setTabletTracking(False)
        self.move_up.setText("")
        icon3 = QtGui.QIcon()
        icon3.addPixmap(QtGui.QPixmap("media/arrow_up.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.move_up.setIcon(icon3)
        self.move_up.setCheckable(False)
        self.move_up.setFlat(True)
        self.move_up.setObjectName("move_up")
        self.gridLayout_6.addWidget(self.move_up, 1, 1, 1, 1)
        self.reverse_x = QtWidgets.QCheckBox(self.centralwidget)
        self.reverse_x.setObjectName("reverse_x")
        self.gridLayout_6.addWidget(self.reverse_x, 0, 0, 1, 1)
        self.switchxy = QtWidgets.QCheckBox(self.centralwidget)
        self.switchxy.setObjectName("switchxy")
        self.gridLayout_6.addWidget(self.switchxy, 0, 2, 1, 1)
        self.move_down = QtWidgets.QPushButton(self.centralwidget)
        self.move_down.setText("")
        icon4 = QtGui.QIcon()
        icon4.addPixmap(QtGui.QPixmap("media/arrow_down.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.move_down.setIcon(icon4)
        self.move_down.setFlat(True)
        self.move_down.setObjectName("move_down")
        self.gridLayout_6.addWidget(self.move_down, 3, 1, 1, 1)
        self.move_up_left = QtWidgets.QPushButton(self.centralwidget)
        self.move_up_left.setText("")
        icon5 = QtGui.QIcon()
        icon5.addPixmap(QtGui.QPixmap("media/arrow_up_left.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.move_up_left.setIcon(icon5)
        self.move_up_left.setFlat(True)
        self.move_up_left.setObjectName("move_up_left")
        self.gridLayout_6.addWidget(self.move_up_left, 1, 0, 1, 1)
        self.move_up_right = QtWidgets.QPushButton(self.centralwidget)
        self.move_up_right.setText("")
        icon6 = QtGui.QIcon()
        icon6.addPixmap(QtGui.QPixmap("media/arrow_up_right.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.move_up_right.setIcon(icon6)
        self.move_up_right.setFlat(True)
        self.move_up_right.setObjectName("move_up_right")
        self.gridLayout_6.addWidget(self.move_up_right, 1, 2, 1, 1)
        self.move_down_left = QtWidgets.QPushButton(self.centralwidget)
        self.move_down_left.setText("")
        icon7 = QtGui.QIcon()
        icon7.addPixmap(QtGui.QPixmap("media/arrow_down_left.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.move_down_left.setIcon(icon7)
        self.move_down_left.setFlat(True)
        self.move_down_left.setObjectName("move_down_left")
        self.gridLayout_6.addWidget(self.move_down_left, 3, 0, 1, 1)
        self.pushButton_5 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_5.setText("")
        icon8 = QtGui.QIcon()
        icon8.addPixmap(QtGui.QPixmap("media/arrow_down_right.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.pushButton_5.setIcon(icon8)
        self.pushButton_5.setFlat(True)
        self.pushButton_5.setObjectName("pushButton_5")
        self.gridLayout_6.addWidget(self.pushButton_5, 3, 2, 1, 1)
        self.verticalLayout_4.addLayout(self.gridLayout_6)
        self.gridLayout_2.addLayout(self.verticalLayout_4, 0, 3, 1, 1)
        self.calendarWidget = QtWidgets.QCalendarWidget(self.centralwidget)
        self.calendarWidget.setObjectName("calendarWidget")
        self.gridLayout_2.addWidget(self.calendarWidget, 0, 2, 1, 1)
        MainWindow.setCentralWidget(self.centralwidget)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 1501, 25))
        self.menubar.setObjectName("menubar")
        self.menuFile = QtWidgets.QMenu(self.menubar)
        self.menuFile.setObjectName("menuFile")
        self.menuConnect = QtWidgets.QMenu(self.menubar)
        self.menuConnect.setObjectName("menuConnect")
        MainWindow.setMenuBar(self.menubar)
        self.actionSave = QtWidgets.QAction(MainWindow)
        self.actionSave.setObjectName("actionSave")
        self.actionNew = QtWidgets.QAction(MainWindow)
        self.actionNew.setObjectName("actionNew")
        self.actionOpen = QtWidgets.QAction(MainWindow)
        self.actionOpen.setObjectName("actionOpen")
        self.actionConnect_X = QtWidgets.QAction(MainWindow)
        self.actionConnect_X.setObjectName("actionConnect_X")
        self.actionConnect_Y = QtWidgets.QAction(MainWindow)
        self.actionConnect_Y.setObjectName("actionConnect_Y")
        self.actionClose = QtWidgets.QAction(MainWindow)
        self.actionClose.setObjectName("actionClose")
        self.menuFile.addAction(self.actionSave)
        self.menuFile.addAction(self.actionNew)
        self.menuFile.addAction(self.actionOpen)
        self.menuFile.addAction(self.actionClose)
        self.menuConnect.addSeparator()
        self.menuConnect.addAction(self.actionConnect_X)
        self.menuConnect.addAction(self.actionConnect_Y)
        self.menubar.addAction(self.menuFile.menuAction())
        self.menubar.addAction(self.menuConnect.menuAction())

        self.retranslateUi(MainWindow)
        self.speed_slider.valueChanged['int'].connect(self.speed_textbox.setValue)
        self.speed_textbox.valueChanged['int'].connect(self.speed_slider.setValue)
        self.actionClose.triggered.connect(MainWindow.close)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        __sortingEnabled = self.listWidget.isSortingEnabled()
        self.listWidget.setSortingEnabled(False)
        item = self.listWidget.item(0)
        item.setText(_translate("MainWindow", "Pos1"))
        item = self.listWidget.item(1)
        item.setText(_translate("MainWindow", "Delay (360s)"))
        item = self.listWidget.item(2)
        item.setText(_translate("MainWindow", "Pos2"))
        self.listWidget.setSortingEnabled(__sortingEnabled)
        self.pushButton_2.setText(_translate("MainWindow", "Delete Selected"))
        self.pushButton.setText(_translate("MainWindow", "Add Delay"))
        self.label.setText(_translate("MainWindow", "Moving Speed"))
        self.speed_slowest.setWhatsThis(_translate("MainWindow", "50hz "))
        self.speed_slowest.setText(_translate("MainWindow", "slowest"))
        self.speed_slow.setWhatsThis(_translate("MainWindow", "1kHz"))
        self.speed_slow.setText(_translate("MainWindow", "slow"))
        self.speed_fast.setWhatsThis(_translate("MainWindow", "5kHz"))
        self.speed_fast.setText(_translate("MainWindow", "fast"))
        self.speed_fastest.setWhatsThis(_translate("MainWindow", "10kHz"))
        self.speed_fastest.setText(_translate("MainWindow", "fastest"))
        self.move_right.setShortcut(_translate("MainWindow", "Right"))
        self.move_left.setShortcut(_translate("MainWindow", "Left"))
        self.pushButton_6.setWhatsThis(_translate("MainWindow", "Save current position to list"))
        self.pushButton_6.setText(_translate("MainWindow", "Add Position"))
        self.pushButton_6.setShortcut(_translate("MainWindow", "Return"))
        self.reverse_y.setText(_translate("MainWindow", "Reverse Y"))
        self.move_up.setShortcut(_translate("MainWindow", "Up"))
        self.reverse_x.setText(_translate("MainWindow", "Reverse X"))
        self.switchxy.setText(_translate("MainWindow", "Switch X Y"))
        self.move_down.setShortcut(_translate("MainWindow", "Down"))
        self.menuFile.setTitle(_translate("MainWindow", "File"))
        self.menuConnect.setTitle(_translate("MainWindow", "Connect"))
        self.actionSave.setText(_translate("MainWindow", "Save"))
        self.actionSave.setStatusTip(_translate("MainWindow", "Save existing configuration"))
        self.actionSave.setShortcut(_translate("MainWindow", "Ctrl+S"))
        self.actionNew.setText(_translate("MainWindow", "New"))
        self.actionNew.setStatusTip(_translate("MainWindow", "Create new configuration"))
        self.actionOpen.setText(_translate("MainWindow", "Open"))
        self.actionConnect_X.setText(_translate("MainWindow", "Connect X"))
        self.actionConnect_Y.setText(_translate("MainWindow", "Connect Y"))
        self.actionClose.setText(_translate("MainWindow", "Close"))
        self.actionClose.setShortcut(_translate("MainWindow", "Ctrl+X"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    app.setStyle('QtCurve')
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /home/jynx/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3425: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
